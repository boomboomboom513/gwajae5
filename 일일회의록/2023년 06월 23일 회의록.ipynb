# %% [markdown]
# # 06월 23일 회의내용
# #### 주제 : 같은 종목, 같은 데이터로 다양한 알고리즘 모델 만들어보기
#
#
# 1. 'SK 하이닉스'의 뉴스데이터를 이용하여 단어별 빈도수 추출 Tokenizer
# 2. 빈도수 추출하여 많이 나온 단어의 긍, 부정 판별하여 주식 데이터의 영향이 있는지 확인
# 3. 각자 아이디어로 모델 만들어보기
# 4. 만들어보면서 어떤 이슈가 있었는지, 어떤 아이디어로 모델을 만들었는지 등 각자 정리해서 다음주 회의 때 이야기하기
#
# #### < 저장 방법 >
# - 각자 폴더에 제목양식 맞춰 올려주세요~!
# - 제목양식 : '날짜_이름_사용한 알고리즘' ex) '0623_박효민_CNN'
