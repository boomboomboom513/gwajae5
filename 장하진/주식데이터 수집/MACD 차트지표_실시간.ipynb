# %% [markdown]
# 클래스 설명
#
#   - class CpStockChart: 차트 데이터 수신
#
#   - class CpEvent: 실시간 시세 수신
#
#   - class MyWindow : 기본 UI 클래스
#
#
#
# 예제에서 사용한 PLUS OBJECT
#
#   - CpSysDib.StockChart : 차트 기본 데이터 수신(일주월분틱 별  시가, 고가, 저가, 고가, 거래량 등)
#
#   - DsCbo1.StockCur : 현재가 실시간 데이터 수신
#
#   - CpIndexes.CpSeries : 차트 지표 계산을 위한 중간 OBJECT
#
#   - CpIndexes.CpIndex : 실질적인 지표 계산 OBJECT 로 MACD, 이동평균, CCI, STOCHASTIC 등 다양한 지표 계산 및 시그널 발생도 가능
#
#
#
#
# PLUS API 를 사용하여 MACD 지표 구하는 기본 적인 방법
#
#   1. 차트 데이터 통신
#
#   2. 수신 받은 차트 데이터를 CpIndexes.CpSeries 에 역순으로 입력
#
#   3. CpIndexes.CpIndex 를 이용하여 MACD 계산
#
#
# PLUS API 를 사용하여 MACD 실시간 update 하기
#
#   1. DsCbo1.StockCur 를 이용하여 실시간 현재가 수신
#
#   2. 실시간 현재가 정보를 CpIndexes.CpSeries 에 update (update 함수)
#
#   3. CpIndexes.CpIndex 에서 재 계산(update 함수)

# %%
import sys
from PyQt5.QtWidgets import *
import win32com.client

# %%
# 요약: MACD 지표 데이터 실시간 구하기
#     : 차트 OBJECT 를 통해 차트 데이터를 받은 후
#     : 지표 실시간 계산 OBJECT 를 통해 지표 데이터를 계산
 
class CpEvent:
    def set_params(self, client, objCaller):
        self.client = client
        self.caller = objCaller
 
    def OnReceived(self):
        code = self.client.GetHeaderValue(0)  # 초
        name = self.client.GetHeaderValue(1)  # 초
        timess = self.client.GetHeaderValue(18)  # 초
        exFlag = self.client.GetHeaderValue(19)  # 예상체결 플래그
        cprice = self.client.GetHeaderValue(13)  # 현재가
        diff = self.client.GetHeaderValue(2)  # 대비
        cVol = self.client.GetHeaderValue(17)  # 순간체결수량
        vol = self.client.GetHeaderValue(9)  # 거래량
        open = self.client.GetHeaderValue(4)  # 고가
        high = self.client.GetHeaderValue(5)  # 고가
        low = self.client.GetHeaderValue(6)  # 저가
 
        if (exFlag == ord('1')):  # 동시호가 시간 (예상체결)
            print("실시간(예상체결)", name, timess, "*", cprice, "대비", diff, "체결량", cVol, "거래량", vol)
            return  # 차트는 예상 체결 시간 update 없음.
        elif (exFlag == ord('2')):  # 장중(체결)
            print("실시간(장중 체결)", name, timess, cprice, "대비", diff, "체결량", cVol, "거래량", vol)
 
        # MACD 지표 update 함수 호출
        self.caller.updateMACD(cprice, open, high, low, vol)

# %%
class CpStockChart:
    def __init__(self):
        self.objCpCybos = win32com.client.Dispatch("CpUtil.CpCybos")
        self.objStockChart = win32com.client.Dispatch("CpSysDib.StockChart")
 
    def Request(self, code, objCaller):
        # 연결 여부 체크
        bConnect = self.objCpCybos.IsConnect
        if (bConnect == 0):
            print("PLUS가 정상적으로 연결되지 않음. ")
            return False
 
        print("111")
        # 현재가 객체 구하기
        self.objStockChart.SetInputValue(0, code)  # 종목 코드 - 삼성전자
        self.objStockChart.SetInputValue(1, ord('2'))  # 개수로 조회
        self.objStockChart.SetInputValue(4, 500)  # 최근 500일치
        self.objStockChart.SetInputValue(5, [0, 2, 3, 4, 5, 8])  # 날짜,시가,고가,저가,종가,거래량
        self.objStockChart.SetInputValue(6, ord('D'))  # '차트 주기 - 일간 차트 요청
        self.objStockChart.SetInputValue(9, ord('1'))  # 수정주가 사용
        self.objStockChart.BlockRequest()
 
        rqStatus = self.objStockChart.GetDibStatus()
        rqRet = self.objStockChart.GetDibMsg1()
        print("통신상태", rqStatus, rqRet)
        if rqStatus != 0:
            exit()
 
        # MACD 지표 계산 함수 호출
        objCaller.makeChartSeries(self.objStockChart)

# %%
class CpStockCur:
    def Subscribe(self, code, objIndex):
        self.objStockCur = win32com.client.Dispatch("DsCbo1.StockCur")
        handler = win32com.client.WithEvents(self.objStockCur, CpEvent)
        self.objStockCur.SetInputValue(0, code)
        handler.set_params(self.objStockCur, objIndex)
        self.objStockCur.Subscribe()
 
    def Unsubscribe(self):
        self.objStockCur.Unsubscribe()

# %%
class MyWindow(QMainWindow):
 
    def __init__(self):
        super().__init__()
        self.setWindowTitle("PLUS API TEST")
        self.setGeometry(300, 300, 300, 150)
        self.isSB = False
        self.objCur = []
 
        btnStart = QPushButton("요청 시작", self)
        btnStart.move(20, 20)
        btnStart.clicked.connect(self.btnStart_clicked)
 
        btnStop = QPushButton("요청 종료", self)
        btnStop.move(20, 70)
        btnStop.clicked.connect(self.btnStop_clicked)
 
        btnExit = QPushButton("종료", self)
        btnExit.move(20, 120)
        btnExit.clicked.connect(self.btnExit_clicked)
 
        # obj 미리 선언
 
 
    def StopSubscribe(self):
        if self.isSB:
            cnt = len(self.objCur)
            for i in range(cnt):
                self.objCur[i].Unsubscribe()
            print(cnt, "종목 실시간 해지되었음")
        self.isSB = False
 
        self.objCur = []
 
    def btnStart_clicked(self):
        self.StopSubscribe();
 
        # 요청 종목
        code = "A338220"
 
        # 지표 계산을 위한 시리즈 선언 - 차트 데이터 수신 받아 데이터를 넣어야 함.
        self.objSeries = win32com.client.Dispatch("CpIndexes.CpSeries")
 
        # 1. 차트 데이터 통신 요청
        self.objChart = CpStockChart()
        if self.objChart.Request(code,  self) == False:
            exit()
 
        # 2. macd 지표 만들기
        self.makeMACD()
 
 
       # 3. 현재가 실시간 요청하기
        self.objCur.append(CpStockCur())
        self.objCur[0].Subscribe(code,self)
 
        print("빼기빼기================-")
        print("종목 실시간 현재가 요청 시작")
        self.isSB = True
 
    def btnStop_clicked(self):
        self.StopSubscribe()
 
 
    def btnExit_clicked(self):
        self.StopSubscribe()
        exit()
 
    # 차트 수신 데이터 --> 시리즈 생성
    # 차트 수신 데이터의 경우 최근 데이터가 맨 앞에 있으나
    # 시리즈는 반대로 넣어야 함.
    # 차트 데이터를 가져와 역순으로 시리즈에 넣는 작업 필요
    def makeChartSeries(self, objStockChart):
        len = objStockChart.GetHeaderValue(3)
 
        print("날짜", "시가", "고가", "저가", "종가", "거래량")
        print("빼기빼기==============================================-")
 
        for i in range(len):
            day = objStockChart.GetDataValue(0, len - i - 1)
            open = objStockChart.GetDataValue(1, len - i - 1)
            high = objStockChart.GetDataValue(2, len - i - 1)
            low = objStockChart.GetDataValue(3, len - i - 1)
            close = objStockChart.GetDataValue(4, len - i - 1)
            vol = objStockChart.GetDataValue(5, len - i - 1)
            print(day, open, high, low, close, vol)
            # objSeries.Add 종가, 시가, 고가, 저가, 거래량, 코멘트
            self.objSeries.Add(close, open, high, low, vol)
        return
 
    # CpIndex 를 이용하여 MACD 지표 계산
    # MACD 는 총 3가지 지표가 들어 있음(MACD, SIGNAL, OSCILLATOR)
    # 최근 데이터는 지표의 맨 마지막 데이터에 들어 있음.
    def makeMACD(self):
        # 지표 계산 object
        self.objIndex = win32com.client.Dispatch("CpIndexes.CpIndex")
        self.objIndex.series = self.objSeries
        self.objIndex.put_IndexKind("MACD")     # 계산할 지표: MACD
        self.objIndex.put_IndexDefault("MACD")  # MACD 지표 기본 변수 자동 세팅
 
        print("MACD 변수", self.objIndex.get_Term1(), self.objIndex.get_Term2(), self.objIndex.get_Signal())
 
        # 지표 데이터 계산 하기
        self.objIndex.Calculate()
 
        cntofIndex = self.objIndex.ItemCount
        print("지표 개수:  ", cntofIndex )
        indexName = ["MACD", "SIGNAL", "OSCILLATOR"]
        for index in range(cntofIndex):
            cnt = self.objIndex.GetCount(index)
            #for j in range(cnt) :
            #    value = self.objIndex.GetResult(index,j)
            value = self.objIndex.GetResult(index, cnt - 1) # 지표의 가장 최근 값 - 맨 뒤 데이터
            print(indexName[index], value)  # 지표의 최근 값 표시
 
    # 실시간 시세 수신 받아 MACD 계산
    def updateMACD(self, cprice, open, high, low, vol):
        # 지표 데이터 update
        self.objSeries.update(cprice, open, high, low, vol)
        self.objIndex.update()
        cntofIndex = self.objIndex.ItemCount
        print("지표 개수:  ", cntofIndex )
 
        indexName = ["MACD", "SIGNAL", "OSCILLATOR"]
 
        for index in range(cntofIndex):
            cnt = self.objIndex.GetCount(index)
            # print(index , "번째 지표의 데이터 개수", cnt)
            value = self.objIndex.GetResult(index, cnt - 1) # 지표의 가장 최근 값 - 맨 뒤 데이터
            print(indexName[index], value)  # 지표의 최근 값 표시
            
    def save_to_csv(self, filename, data):
        with open(filename, 'w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(['종목코드', '종목명', '시간', '대비부호', '대비', '현재가', '거래량'])
            for row in data:
                writer.writerow(row)        
 
        return

# %%
if __name__ == "__main__":
    app = QApplication(sys.argv)
    myWindow = MyWindow()
    myWindow.show()
    app.exec_()
# Out:
# 111
# 통신상태 0
# 날짜 시가 고가 저가 종가 거래량
# 빼기빼기==============================================-
# 20210617 21350 22050 21300 21650 92586
# 20210618 21700 22100 21600 21900 63946
# 20210621 21650 21800 21050 21050 96859
# 20210622 21100 21400 21050 21350 37964
# 20210623 21200 21950 21200 21750 67628
# 20210624 21800 23700 21750 22400 381094
# 20210625 22600 22850 21850 22000 180595
# 20210628 22150 22200 21450 21500 115771
# 20210629 21550 25150 21550 22150 650151
# 20210630 22200 22550 21950 21950 185639
# 20210701 22350 22700 21950 22600 106986
# 20210702 22550 22750 22200 22300 91072
# 20210705 22650 23800 22350 23500 250694
# 20210706 23600 24050 23200 23500 184737
# 20210707 23500 23500 23050 23200 107437
# 20210708 23200 23400 22050 22400 178044
# 20210709 22100 22600 21750 22450 101193
# 20210712 22550 22650 22350 22600 66881
# 20210713 22650 22950 22250 22800 72160
# 20210714 22850 22850 22250 22400 78164
# 20210715 22550 22550 22200 22350 57804
# 20210716 22350 22850 22200 22850 68462
# 20210719 22900 23950 22550 23500 222945
# 20210720 23250 26200 23200 24100 836682
# 20210721 24150 25800 24100 25650 503763
# 20210722 25350 26750 25050 25600 411269
# 20210723 25550 25850 24450 24800 229104
# 20210726 24500 24650 23800 24000 171310
# 20210727 24000 24750 23950 24350 99437
# 20210728 24100 25550 23550 24000 201492
# 20210729 24000 24500 23800 23900 90867
# 20210730 24150 24250 23550 23650 89776
# 20210802 23500 23650 22800 23400 89954
# 20210803 23400 23450 22950 23150 67807
# 20210804 23200 24200 23150 24150 84584
# 20210805 24000 24550 23850 24200 91805
# 20210806 24200 24250 23600 23800 64545
# 20210809 23900 24000 23200 23350 69739
# 20210810 23300 23750 22700 23200 121893
# 20210811 23500 24500 23350 23900 243111
# 20210812 24150 28200 24100 26950 2123223
# 20210813 26900 26950 25250 26000 524464
# 20210817 25500 25600 23800 23800 355760
# 20210818 23500 24250 22750 24000 197305
# 20210819 23400 24000 22700 22700 160485
# 20210820 22700 22900 21500 21600 135117
# 20210823 22050 22700 21700 22350 67551
# 20210824 22350 23800 22350 22850 94069
# 20210825 23400 23800 22900 23500 117309
# 20210826 23350 23350 22450 22550 113769
# 20210827 22450 22600 21850 22400 69964
# 20210830 22550 23050 22500 22700 55450
# 20210831 23150 23200 22650 22650 45057
# 20210901 22800 22800 22300 22600 52607
# 20210902 22650 23550 22550 22700 113303
# 20210903 23000 23250 22800 22850 52372
# 20210906 23250 23250 22500 22750 58773
# 20210907 22550 22750 22200 22400 70459
# 20210908 22400 22400 21650 21650 100112
# 20210909 21500 22200 21350 21800 55906
# 20210910 21800 22250 21500 22000 53524
# 20210913 22000 22250 21600 21900 43807
# 20210914 21900 22500 21700 22350 50631
# 20210915 22450 22950 22200 22900 77544
# 20210916 22950 22950 22500 22650 29862
# 20210917 22650 22700 22150 22550 31477
# 20210923 22250 22450 21500 22000 45127
# 20210924 21950 22650 21750 22150 44141
# 20210927 22000 22350 21850 22100 24915
# 20210928 21900 21950 20900 20900 130581
# 20210929 20450 22250 19750 21300 134638
# 20210930 21350 21350 20650 20800 35471
# 20211001 20750 21400 20500 20750 55910
# 20211005 20750 20750 19750 19750 58063
# 20211006 19700 20300 18700 18800 77229
# 20211007 18800 19600 18800 19400 42054
# 20211008 19400 19600 18900 19100 31497
# 20211012 18950 19050 18000 18350 73158
# 20211013 18100 19000 18100 18650 22538
# 20211014 18700 19350 18450 19100 27001
# 20211015 19100 19450 18950 19250 23963
# 20211018 19300 19600 19050 19300 16710
# 20211019 19100 19450 19100 19450 18259
# 20211020 19450 20250 19250 19400 30261
# 20211021 19350 19800 19050 19300 22886
# 20211022 19300 19300 18850 19300 21029
# 20211025 19300 20000 19000 19350 29464
# 20211026 19700 19750 19400 19750 25081
# 20211027 19750 19900 19450 19650 14641
# 20211028 19900 19900 19250 19400 30764
# 20211029 19400 19500 19000 19200 36273
# 20211101 19500 19500 18900 19000 21035
# 20211102 19000 19550 19000 19500 26308
# 20211103 19650 20300 19500 19500 53593
# 20211104 20050 20050 19350 19950 54680
# 20211105 19700 19950 19350 19600 30728
# 20211108 19550 19550 18900 19200 41939
# 20211109 19200 19400 19000 19200 16699
# 20211110 19200 19200 18050 18500 69313
# 20211111 18200 18500 17950 18050 38579
# 20211112 18450 18450 18050 18200 18489
# 20211115 18300 18750 18200 18600 26968
# 20211116 18250 18550 18150 18500 35663
# 20211117 18450 18900 18150 18350 33995
# 20211118 18150 19000 17800 18950 53738
# 20211119 18900 19650 18550 19600 82245
# 20211122 19800 20000 19050 19550 53614
# 20211123 19200 19550 18750 18750 34152
# 20211124 18750 19000 18350 18900 31175
# 20211125 19150 19150 18450 18450 26996
# 20211126 18700 19300 18500 18700 48620
# 20211129 17900 18800 17600 18200 31255
# 20211130 18300 18600 17550 17750 38901
# 20211201 17550 18250 17400 17850 26608
# 20211202 17850 19050 17600 18550 33823
# 20211203 18350 18800 18350 18550 19494
# 20211206 18350 18500 17950 18200 30909
# 20211207 18100 18500 17800 18450 27583
# 20211208 18450 18800 18350 18500 25027
# 20211209 18950 20200 18700 19750 149586
# 20211210 19750 19900 19100 19750 35560
# 20211213 19800 20600 19400 20400 99926
# 20211214 20400 20800 19850 20150 72051
# 20211215 20400 20400 19600 19850 32467
# 20211216 20150 20950 19850 19900 101891
# 20211217 19900 19950 19500 19600 37750
# 20211220 19600 19700 19250 19700 33088
# 20211221 20050 20500 19000 19250 134160
# 20211222 19250 19450 18250 18500 1471213
# 20211223 18600 19200 18450 18500 61637
# 20211224 18700 18900 18350 18550 33997
# 20211227 18800 18800 18400 18550 32519
# 20211228 18650 18650 17950 18300 74606
# 20211229 18050 18700 18050 18550 30626
# 20211230 18650 19150 18650 18900 60224
# 20220103 19100 19250 18250 18950 66676
# 20220104 19200 19350 18750 19200 75765
# 20220105 19200 19300 18400 18750 70388
# 20220106 18350 18600 17800 17900 97027
# 20220107 18100 18250 17850 18050 56940
# 20220110 18050 18050 17450 17650 78248
# 20220111 17800 17800 17050 17100 62145
# 20220112 17200 17400 16850 16900 116671
# 20220113 17050 17050 16400 16700 85500
# 20220114 16500 16700 16300 16350 44791
# 20220117 16300 16350 15700 15750 85322
# 20220118 15900 16000 14700 14700 83023
# 20220119 14600 14950 14200 14500 88255
# 20220120 14400 14700 14050 14450 116671
# 20220121 14400 15000 14100 14150 67333
# 20220124 14150 14350 12750 13350 126360
# 20220125 13600 13600 12500 12600 94567
# 20220126 12700 12950 12300 12450 80405
# 20220127 12550 12600 11700 11950 105928
# 20220128 12200 12500 11900 12350 92203
# 20220203 12750 12750 11950 12200 184195
# 20220204 12100 12300 11800 12050 123059
# 20220207 12150 12600 12100 12350 74269
# 20220208 12350 12450 11700 11950 139266
# 20220209 11950 12800 11850 12500 111098
# 20220210 12500 12500 11950 12100 76365
# 20220211 11900 12000 11350 11350 125828
# 20220214 10950 11100 10050 10250 295111
# 20220215 10350 10400 9910 9970 141404
# 20220216 10100 10300 10000 10300 91411
# 20220217 10250 10400 9820 10100 142564
# 20220218 9980 10600 9830 10400 108010
# 20220221 10300 10500 10250 10450 47500
# 20220222 10250 10400 9980 10000 60002
# 20220223 10050 10300 9990 10100 31817
# 20220224 9990 10050 9400 9410 124926
# 20220225 9600 9860 9590 9670 41746
# 20220228 9770 9940 9720 9940 31670
# 20220302 9850 10050 9700 9960 52406
# 20220303 9960 10300 9960 10150 57205
# 20220304 10200 10250 9910 10050 43034
# 20220307 9970 9980 9600 9710 56537
# 20220308 9580 9790 9410 9660 55439
# 20220310 9800 10050 9800 9990 45170
# 20220311 9990 10950 9990 10450 256072
# 20220314 10450 10550 9830 9920 87170
# 20220315 9860 10350 9610 9900 94092
# 20220316 10050 10850 10000 10650 126988
# 20220317 10700 11650 10450 11100 429270
# 20220318 11150 11150 10800 10950 94757
# 20220321 11050 11100 10650 10700 63114
# 20220322 10700 10800 10400 10800 48568
# 20220323 10800 10900 10600 10700 57940
# 20220324 10900 10900 10350 10800 53542
# 20220325 10900 10900 10400 10700 58780
# 20220328 10500 11000 10500 10800 60489
# 20220329 10800 10900 10650 10850 41691
# 20220330 10900 11450 10850 11150 114420
# 20220331 11100 11200 10900 11050 54032
# 20220401 11050 11800 10950 11300 161404
# 20220404 11400 11950 11350 11850 125538
# 20220405 12000 13450 11700 13350 566721
# 20220406 13350 13400 12400 12600 225111
# 20220407 12450 12800 11950 12150 134201
# 20220408 12150 12300 11700 12000 88110
# 20220411 11900 12300 11800 11950 56782
# 20220412 11700 11800 11350 11500 58353
# 20220413 11500 11950 11500 11750 56427
# 20220414 11850 11850 11500 11600 47834
# 20220415 11650 11650 11300 11450 31171
# 20220418 11450 11450 10650 10800 90301
# 20220419 10900 11150 10850 11050 27360
# 20220420 11200 11200 10800 10900 34465
# 20220421 11000 11000 10650 10750 31519
# 20220422 10600 11300 10500 10650 101327
# 20220425 10650 10650 10100 10200 47887
# 20220426 10300 10750 10250 10550 22393
# 20220427 10200 10450 10050 10400 25645
# 20220428 10400 10400 10050 10200 31800
# 20220429 10200 10700 10200 10700 23996
# 20220502 10500 10700 10300 10500 18959
# 20220503 10550 10900 10500 10750 22945
# 20220504 10750 10800 10600 10650 19054
# 20220506 10650 10800 10450 10650 41281
# 20220509 10850 10850 10150 10250 24867
# 20220510 10150 10150 9600 10000 41742
# 20220511 9880 10150 9880 10050 14737
# 20220512 9950 10500 9660 9670 115663
# 20220513 9770 10000 9760 9820 15930
# 20220516 9810 10250 9810 9860 24522
# 20220517 9950 10000 9900 9940 16335
# 20220518 10000 10750 10000 10500 85591
# 20220519 10850 10850 10400 10500 57416
# 20220520 10550 10700 10400 10700 22228
# 20220523 10700 10700 10500 10650 14957
# 20220524 10550 10700 10350 10400 14092
# 20220525 10400 10600 10200 10300 38205
# 20220526 10350 10500 9970 10000 40488
# 20220527 10100 10300 10000 10100 26240
# 20220530 10150 10250 10100 10250 15518
# 20220531 10150 10400 10050 10250 41669
# 20220602 10300 10350 10100 10200 12845
# 20220603 10200 10700 10150 10500 58510
# 20220607 10450 10450 10000 10000 47644
# 20220608 10050 10100 9870 9900 31870
# 20220609 10250 10250 9700 9940 67527
# 20220610 9820 10150 9820 9930 35251
# 20220613 9780 9780 9420 9470 54983
# 20220614 9100 9320 8900 9020 72994
# 20220615 9050 9110 8540 8650 64077
# 20220616 8850 9020 8730 8780 22680
# 20220617 8550 8590 8380 8500 48669
# 20220620 8650 8650 7880 7900 60507
# 20220621 7870 8000 7730 7990 38966
# 20220622 7940 8220 7150 7440 72206
# 20220623 7460 7640 7260 7490 50895
# 20220624 7510 7750 7410 7700 48642
# 20220627 7710 8090 7610 8020 43983
# 20220628 7940 8090 7830 7920 18139
# 20220629 7920 8060 7740 8000 26823
# 20220630 8000 8040 7840 7900 20828
# 20220701 7910 8100 7320 7600 39750
# 20220704 7790 7920 7540 7590 26475
# 20220705 7630 7990 7630 7920 19750
# 20220706 7920 8140 7860 8030 40172
# 20220707 8110 8300 8060 8150 30987
# 20220708 8150 8200 8040 8120 21871
# 20220711 8110 8300 8050 8190 27043
# 20220712 8190 8370 7830 7890 24042
# 20220713 7900 8000 7730 7940 27043
# 20220714 7940 8050 7790 7960 25161
# 20220715 7970 8200 7820 7910 15113
# 20220718 7990 8220 7910 8180 31766
# 20220719 8180 8200 8050 8140 23163
# 20220720 8220 8250 7920 8000 321260
# 20220721 8090 8090 7290 7570 279412
# 20220722 7600 7780 7360 7570 139145
# 20220725 7570 7670 7400 7490 85676
# 20220726 7490 7550 7370 7400 44995
# 20220727 7480 7800 7340 7630 123310
# 20220728 7700 7790 7420 7470 59348
# 20220729 7490 7640 7410 7560 67239
# 20220801 7680 7680 7450 7600 45059
# 20220802 7550 7910 7510 7730 155074
# 20220803 7640 8470 7640 7980 321386
# 20220804 8020 8310 8020 8050 111009
# 20220805 8050 8230 8010 8230 49429
# 20220808 8260 8260 7970 7980 55192
# 20220809 7870 7940 7790 7890 48454
# 20220810 7810 7880 7650 7700 52482
# 20220811 7940 7940 7690 7700 42153
# 20220812 7830 7830 7620 7690 18253
# 20220816 7690 7690 7450 7470 79090
# 20220817 7500 7500 7180 7200 97543
# 20220818 7300 7300 7040 7150 38268
# 20220819 7200 7250 7040 7180 32663
# 20220822 7230 7230 6990 7020 54207
# 20220823 7060 7060 6750 6830 96905
# 20220824 6830 6870 6750 6790 42023
# 20220825 6900 7030 6790 6840 160738
# 20220826 6920 6920 6760 6780 47879
# 20220829 6680 6690 6520 6520 58268
# 20220830 6510 6620 6500 6600 23348
# 20220831 6500 6750 6490 6740 38177
# 20220901 6750 6750 6590 6610 37067
# 20220902 6570 6620 6430 6430 33760
# 20220905 6500 6500 6280 6410 41828
# 20220906 6440 6470 6350 6380 22852
# 20220907 6400 6400 6050 6050 55313
# 20220908 6120 6280 6110 6130 25489
# 20220913 6190 6340 6190 6260 18295
# 20220914 6130 7340 5960 6400 379131
# 20220915 6400 6510 6300 6300 42189
# 20220916 6350 6490 6210 6300 24737
# 20220919 6370 6430 6190 6190 24746
# 20220920 6190 6380 6180 6190 12727
# 20220921 6260 6270 6060 6150 17399
# 20220922 6070 6080 5960 5990 32032
# 20220923 6020 6020 5730 5800 34676
# 20220926 5620 5800 5320 5450 56368
# 20220927 5440 5580 5400 5510 21127
# 20220928 5680 5680 5120 5230 49310
# 20220929 5270 5790 5270 5490 84356
# 20220930 5500 5580 5370 5460 37715
# 20221004 5510 5710 5510 5700 28185
# 20221005 5730 5750 5500 5550 26201
# 20221006 5560 6090 5560 5970 69551
# 20221007 5950 6000 5800 5880 17912
# 20221011 5600 5750 5300 5390 41893
# 20221012 5340 5390 5180 5310 24929
# 20221013 5280 5300 5000 5070 30943
# 20221014 5170 5560 5110 5390 32922
# 20221017 5510 5620 5270 5520 22638
# 20221018 5580 6410 5550 5870 272178
# 20221019 5920 5920 5750 5760 26990
# 20221020 5760 5800 5620 5720 18950
# 20221021 5690 5690 5500 5540 18439
# 20221024 5590 5670 5550 5580 13179
# 20221025 5580 5670 5430 5560 14045
# 20221026 5560 5640 5520 5550 8228
# 20221027 5560 5920 5560 5830 42202
# 20221028 5830 6020 5760 5820 43557
# 20221031 5830 5950 5760 5950 14623
# 20221101 5970 6080 5850 6020 19072
# 20221102 6080 6250 5800 6140 35370
# 20221103 6100 6200 5910 5970 24807
# 20221104 5970 5970 5540 5960 22190
# 20221107 6000 6030 5910 5980 16124
# 20221108 5970 6340 5970 6250 89200
# 20221109 6330 6680 6270 6440 67295
# 20221110 6320 6450 6270 6390 11075
# 20221111 6470 6660 6450 6450 44600
# 20221114 6550 6580 6370 6420 15680
# 20221115 6490 6540 6300 6420 13357
# 20221116 6590 6600 6310 6430 19209
# 20221117 6420 6700 6420 6540 37659
# 20221118 6590 6590 6350 6460 8939
# 20221121 6450 6460 6210 6280 13930
# 20221122 6110 6260 5980 6150 17897
# 20221123 6150 6260 6150 6230 10240
# 20221124 6230 6540 6180 6530 37782
# 20221125 6410 6710 6410 6700 37443
# 20221128 6720 6720 6560 6610 16983
# 20221129 6420 6960 6420 6880 50566
# 20221130 6880 6900 6700 6810 36638
# 20221201 7000 7060 6810 6830 37245
# 20221202 6830 6850 6380 6800 15947
# 20221205 6750 7000 6450 6700 20036
# 20221206 6810 7280 6680 6820 155578
# 20221207 6780 6920 6600 6840 17008
# 20221208 6980 6980 6690 6740 16267
# 20221209 6600 6850 6570 6820 12020
# 20221212 6850 6850 6700 6700 9850
# 20221213 6700 7000 6370 6650 24073
# 20221214 6650 6950 6650 6800 24241
# 20221215 6800 6950 6660 6730 14466
# 20221216 6660 6900 6530 6690 15188
# 20221219 6690 6730 6430 6560 13593
# 20221220 6500 6580 6000 6380 21955
# 20221221 6520 6550 6380 6470 10720
# 20221222 6470 6580 6450 6530 6006
# 20221223 6530 6530 6260 6340 12674
# 20221226 6340 6420 6100 6330 13219
# 20221227 6490 6490 6220 6310 7534
# 20221228 6310 6380 6110 6260 12063
# 20221229 6200 6290 6130 6240 15130
# 20230102 6210 6380 6200 6230 11060
# 20230103 6500 6500 6000 6360 17904
# 20230104 6530 6530 6270 6490 20234
# 20230105 6590 6590 6370 6480 8227
# 20230106 6480 6720 6410 6720 21981
# 20230109 6780 6870 6660 6720 13791
# 20230110 6750 6750 6600 6600 12100
# 20230111 6600 6920 6600 6910 32434
# 20230112 6920 6920 6790 6890 11776
# 20230113 6870 7310 6850 7000 107896
# 20230116 7000 7750 7000 7710 425916
# 20230117 7710 8050 7670 7780 232559
# 20230118 7780 8580 7700 8350 417246
# 20230119 8300 8400 7900 8050 122659
# 20230120 8200 8820 8170 8640 260983
# 20230125 8820 9360 8820 9100 344957
# 20230126 9120 9820 8570 8900 620937
# 20230127 8830 9120 8580 8970 164760
# 20230130 9100 9210 8330 8420 230125
# 20230131 8470 9770 8400 9600 808140
# 20230201 9800 10280 9420 9860 546133
# 20230202 9830 10040 9610 10030 227226
# 20230203 9990 9990 9590 9840 141996
# 20230206 9800 9800 9390 9590 107436
# 20230207 9600 10720 9600 10230 527326
# 20230208 10440 11690 10370 11210 765236
# 20230209 11040 12140 10460 12010 736982
# 20230210 11750 11750 10190 10980 657203
# 20230213 10780 10870 10230 10680 258712
# 20230214 10680 11320 10680 10860 239621
# 20230215 10990 11200 10400 10720 194908
# 20230216 10780 11100 10650 10650 120915
# 20230217 10410 10830 10370 10660 112007
# 20230220 10660 11500 10460 10750 203847
# 20230221 10760 11390 10500 10680 140959
# 20230222 10550 10550 9980 10080 147323
# 20230223 10440 12940 10380 11760 2115566
# 20230224 11800 14770 11800 14770 2880600
# 20230227 14770 15640 13700 14330 1271305
# 20230228 14700 18120 14500 16050 3065460
# 20230302 16470 16490 14850 15110 695360
# 20230303 15500 16540 14750 15000 887335
# 20230306 14950 15310 14050 14660 474628
# 20230307 14540 14610 13870 14010 340857
# 20230308 14050 15220 14000 14120 537378
# 20230309 14130 14190 13240 13750 246777
# 20230310 13330 13850 13100 13370 171979
# 20230313 13050 13780 12880 13620 194861
# 20230314 14050 14350 12530 12530 333318
# 20230315 13110 14070 13100 14070 456070
# 20230316 13980 15900 13710 14540 988394
# 20230317 14990 15740 14630 15140 766980
# 20230320 15730 17720 15650 16650 1369662
# 20230321 16410 16600 15360 16060 552193
# 20230322 16300 16500 15670 15850 315163
# 20230323 15600 15800 14890 15040 366653
# 20230324 15100 16130 14810 15550 432169
# 20230327 15540 15540 14720 15250 190929
# 20230328 15210 15340 14800 14860 148447
# 20230329 14850 15720 14410 15670 364640
# 20230330 15870 16390 15440 15960 290663
# 20230331 15770 15830 14900 15100 185517
# 20230403 15100 15550 14240 15320 220945
# 20230404 15490 17590 15490 16650 1037831
# 20230405 17190 19420 16500 18950 2290740
# 20230406 19140 20050 18020 18320 942036
# 20230407 18340 18850 17520 17660 326919
# 20230410 17400 17940 16610 17230 488249
# 20230411 17110 19330 16680 19060 836897
# 20230412 19060 20000 18290 19540 936395
# 20230413 19800 19950 18530 19530 455621
# 20230414 20400 23500 20350 22400 2237207
# 20230417 22400 23200 21150 21650 535433
# 20230418 21600 21600 19950 20450 476052
# 20230419 20400 21150 19770 20700 289773
# 20230420 20400 20400 18720 19000 388672
# 20230421 19210 20500 18850 19110 482094
# 20230424 19050 19600 18500 18590 203207
# 20230425 18590 18590 17360 17520 290334
# 20230426 17520 17630 16710 17170 189218
# 20230427 17110 17330 16600 17100 161958
# 20230428 17300 17700 16170 16580 283566
# 20230502 16800 18400 16600 18400 388152
# 20230503 18220 18550 17820 17970 142828
# 20230504 17860 18410 17540 17630 165231
# 20230508 17630 18280 17370 17590 137893
# 20230509 17840 17840 16610 17010 159209
# 20230510 17030 17790 17030 17150 146174
# 20230511 17680 19740 17420 19400 1057386
# 20230512 19230 21150 18410 21100 800525
# 20230515 20700 22150 19400 19950 752513
# 20230516 19320 21250 18850 21100 718359
# 20230517 21250 22650 20750 21200 761406
# 20230518 21400 21900 19770 19930 523532
# 20230519 20150 20600 19320 19330 302431
# 20230522 19320 20200 18800 19990 217030
# 20230523 20450 21750 19820 19980 617025
# 20230524 19950 21450 19530 21000 611812
# 20230525 21500 22750 20450 21150 951474
# 20230526 21150 21950 20500 20700 379907
# 20230530 20850 21350 19950 20550 286513
# 20230531 20550 20650 19800 19800 298083
# 20230601 19610 21500 19600 20150 710285
# 20230602 20350 24900 20050 23650 3456398
# 20230605 23400 23650 22050 22700 891615
# 20230607 23150 24650 22650 23750 1508435
# 20230608 24800 28150 24500 26250 4042242
# 20230609 26300 28000 25450 28000 1306431
# 20230612 28700 32300 26900 30000 2549777
# 20230613 29700 30000 27400 28750 1154958
# 20230614 28200 28200 26200 26550 970473
# 20230615 26650 27700 26100 26650 540128
# 20230616 27550 29300 27550 28250 1199648
# 20230619 28100 29100 27000 28600 556266
# 20230620 28900 34900 28550 33600 4807987
# 20230621 33600 34100 32150 32950 1166199
# 20230622 32150 34100 30950 32900 874409
# 20230623 33500 37650 33100 34250 2322496
# 20230626 34300 36200 33600 35600 532411
# MACD 변수 12 26 9
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 빼기빼기================-
# 종목 실시간 현재가 요청 시작
# 실시간(장중 체결) 뷰노 94305 35600 대비 1350 체결량 10 거래량 532421
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 실시간(장중 체결) 뷰노 94306 35500 대비 1250 체결량 92 거래량 532513
# 지표 개수:   3
# MACD 3609.666711716134
# SIGNAL 2894.8680588606285
# OSCILLATOR 714.7986528555057
# 실시간(장중 체결) 뷰노 94306 35450 대비 1200 체결량 118 거래량 532631
# 지표 개수:   3
# MACD 3605.67810772753
# SIGNAL 2894.070338062908
# OSCILLATOR 711.6077696646221
# 실시간(장중 체결) 뷰노 94306 35450 대비 1200 체결량 36 거래량 532667
# 지표 개수:   3
# MACD 3605.67810772753
# SIGNAL 2894.070338062908
# OSCILLATOR 711.6077696646221
# 실시간(장중 체결) 뷰노 94307 35450 대비 1200 체결량 11 거래량 532678
# 지표 개수:   3
# MACD 3605.67810772753
# SIGNAL 2894.070338062908
# OSCILLATOR 711.6077696646221
# 실시간(장중 체결) 뷰노 94307 35450 대비 1200 체결량 3 거래량 532681
# 지표 개수:   3
# MACD 3605.67810772753
# SIGNAL 2894.070338062908
# OSCILLATOR 711.6077696646221
# 실시간(장중 체결) 뷰노 94307 35450 대비 1200 체결량 1 거래량 532682
# 지표 개수:   3
# MACD 3605.67810772753
# SIGNAL 2894.070338062908
# OSCILLATOR 711.6077696646221
# 실시간(장중 체결) 뷰노 94307 35600 대비 1350 체결량 2 거래량 532684
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 실시간(장중 체결) 뷰노 94308 35500 대비 1250 체결량 280 거래량 532964
# 지표 개수:   3
# MACD 3609.666711716134
# SIGNAL 2894.8680588606285
# OSCILLATOR 714.7986528555057
# 실시간(장중 체결) 뷰노 94309 35500 대비 1250 체결량 100 거래량 533064
# 지표 개수:   3
# MACD 3609.666711716134
# SIGNAL 2894.8680588606285
# OSCILLATOR 714.7986528555057
# 실시간(장중 체결) 뷰노 94309 35450 대비 1200 체결량 2 거래량 533066
# 지표 개수:   3
# MACD 3605.67810772753
# SIGNAL 2894.070338062908
# OSCILLATOR 711.6077696646221
# 실시간(장중 체결) 뷰노 94309 35500 대비 1250 체결량 29 거래량 533095
# 지표 개수:   3
# MACD 3609.666711716134
# SIGNAL 2894.8680588606285
# OSCILLATOR 714.7986528555057
# 실시간(장중 체결) 뷰노 94310 35500 대비 1250 체결량 110 거래량 533205
# 지표 개수:   3
# MACD 3609.666711716134
# SIGNAL 2894.8680588606285
# OSCILLATOR 714.7986528555057
# 실시간(장중 체결) 뷰노 94310 35550 대비 1300 체결량 16 거래량 533221
# 지표 개수:   3
# MACD 3613.6553157047383
# SIGNAL 2895.6657796583495
# OSCILLATOR 717.9895360463888
# 실시간(장중 체결) 뷰노 94313 35500 대비 1250 체결량 14 거래량 533235
# 지표 개수:   3
# MACD 3609.666711716134
# SIGNAL 2894.8680588606285
# OSCILLATOR 714.7986528555057
# 실시간(장중 체결) 뷰노 94313 35550 대비 1300 체결량 6 거래량 533241
# 지표 개수:   3
# MACD 3613.6553157047383
# SIGNAL 2895.6657796583495
# OSCILLATOR 717.9895360463888
# 실시간(장중 체결) 뷰노 94315 35550 대비 1300 체결량 11 거래량 533252
# 지표 개수:   3
# MACD 3613.6553157047383
# SIGNAL 2895.6657796583495
# OSCILLATOR 717.9895360463888
# 실시간(장중 체결) 뷰노 94315 35550 대비 1300 체결량 1 거래량 533253
# 지표 개수:   3
# MACD 3613.6553157047383
# SIGNAL 2895.6657796583495
# OSCILLATOR 717.9895360463888
# 실시간(장중 체결) 뷰노 94316 35550 대비 1300 체결량 50 거래량 533303
# 지표 개수:   3
# MACD 3613.6553157047383
# SIGNAL 2895.6657796583495
# OSCILLATOR 717.9895360463888
# 실시간(장중 체결) 뷰노 94318 35600 대비 1350 체결량 201 거래량 533504
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 실시간(장중 체결) 뷰노 94318 35550 대비 1300 체결량 85 거래량 533589
# 지표 개수:   3
# MACD 3613.6553157047383
# SIGNAL 2895.6657796583495
# OSCILLATOR 717.9895360463888
# 실시간(장중 체결) 뷰노 94318 35600 대비 1350 체결량 1 거래량 533590
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 실시간(장중 체결) 뷰노 94319 35600 대비 1350 체결량 2 거래량 533592
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 실시간(장중 체결) 뷰노 94319 35550 대비 1300 체결량 52 거래량 533644
# 지표 개수:   3
# MACD 3613.6553157047383
# SIGNAL 2895.6657796583495
# OSCILLATOR 717.9895360463888
# 실시간(장중 체결) 뷰노 94320 35550 대비 1300 체결량 23 거래량 533667
# 지표 개수:   3
# MACD 3613.6553157047383
# SIGNAL 2895.6657796583495
# OSCILLATOR 717.9895360463888
# 실시간(장중 체결) 뷰노 94320 35600 대비 1350 체결량 1 거래량 533668
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 실시간(장중 체결) 뷰노 94320 35600 대비 1350 체결량 64 거래량 533732
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 실시간(장중 체결) 뷰노 94322 35600 대비 1350 체결량 2 거래량 533734
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 실시간(장중 체결) 뷰노 94326 35600 대비 1350 체결량 50 거래량 533784
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 실시간(장중 체결) 뷰노 94327 35600 대비 1350 체결량 10 거래량 533794
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 실시간(장중 체결) 뷰노 94328 35600 대비 1350 체결량 172 거래량 533966
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 실시간(장중 체결) 뷰노 94328 35600 대비 1350 체결량 35 거래량 534001
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 실시간(장중 체결) 뷰노 94329 35550 대비 1300 체결량 130 거래량 534131
# 지표 개수:   3
# MACD 3613.6553157047383
# SIGNAL 2895.6657796583495
# OSCILLATOR 717.9895360463888
# 실시간(장중 체결) 뷰노 94329 35550 대비 1300 체결량 2 거래량 534133
# 지표 개수:   3
# MACD 3613.6553157047383
# SIGNAL 2895.6657796583495
# OSCILLATOR 717.9895360463888
# 실시간(장중 체결) 뷰노 94329 35550 대비 1300 체결량 13 거래량 534146
# 지표 개수:   3
# MACD 3613.6553157047383
# SIGNAL 2895.6657796583495
# OSCILLATOR 717.9895360463888
# 실시간(장중 체결) 뷰노 94331 35600 대비 1350 체결량 100 거래량 534246
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 실시간(장중 체결) 뷰노 94334 35550 대비 1300 체결량 5 거래량 534251
# 지표 개수:   3
# MACD 3613.6553157047383
# SIGNAL 2895.6657796583495
# OSCILLATOR 717.9895360463888
# 실시간(장중 체결) 뷰노 94335 35550 대비 1300 체결량 2 거래량 534253
# 지표 개수:   3
# MACD 3613.6553157047383
# SIGNAL 2895.6657796583495
# OSCILLATOR 717.9895360463888
# 실시간(장중 체결) 뷰노 94338 35600 대비 1350 체결량 56 거래량 534309
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 실시간(장중 체결) 뷰노 94338 35600 대비 1350 체결량 102 거래량 534411
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 실시간(장중 체결) 뷰노 94338 35600 대비 1350 체결량 45 거래량 534456
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 실시간(장중 체결) 뷰노 94338 35650 대비 1400 체결량 13 거래량 534469
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94338 35650 대비 1400 체결량 14 거래량 534483
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94338 35650 대비 1400 체결량 13 거래량 534496
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94338 35650 대비 1400 체결량 4 거래량 534500
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94338 35650 대비 1400 체결량 4 거래량 534504
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94338 35650 대비 1400 체결량 12 거래량 534516
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94338 35650 대비 1400 체결량 20 거래량 534536
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94338 35650 대비 1400 체결량 32 거래량 534568
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94338 35650 대비 1400 체결량 2 거래량 534570
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94339 35650 대비 1400 체결량 238 거래량 534808
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94339 35650 대비 1400 체결량 3 거래량 534811
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94339 35650 대비 1400 체결량 3 거래량 534814
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94339 35650 대비 1400 체결량 3 거래량 534817
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94339 35650 대비 1400 체결량 5 거래량 534822
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94339 35650 대비 1400 체결량 4 거래량 534826
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94339 35650 대비 1400 체결량 5 거래량 534831
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94339 35650 대비 1400 체결량 4 거래량 534835
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94339 35650 대비 1400 체결량 5 거래량 534840
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94339 35650 대비 1400 체결량 4 거래량 534844
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94339 35650 대비 1400 체결량 20 거래량 534864
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94339 35650 대비 1400 체결량 7 거래량 534871
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94339 35650 대비 1400 체결량 8 거래량 534879
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94339 35650 대비 1400 체결량 38 거래량 534917
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94339 35650 대비 1400 체결량 38 거래량 534955
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94339 35650 대비 1400 체결량 3 거래량 534958
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94340 35650 대비 1400 체결량 7 거래량 534965
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94340 35650 대비 1400 체결량 34 거래량 534999
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94340 35650 대비 1400 체결량 7 거래량 535006
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94340 35650 대비 1400 체결량 4 거래량 535010
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94340 35650 대비 1400 체결량 7 거래량 535017
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94340 35650 대비 1400 체결량 14 거래량 535031
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94340 35650 대비 1400 체결량 9 거래량 535040
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94340 35650 대비 1400 체결량 7 거래량 535047
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94340 35650 대비 1400 체결량 9 거래량 535056
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94340 35650 대비 1400 체결량 23 거래량 535079
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94340 35650 대비 1400 체결량 10 거래량 535089
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94340 35650 대비 1400 체결량 33 거래량 535122
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94340 35650 대비 1400 체결량 20 거래량 535142
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94340 35650 대비 1400 체결량 97 거래량 535239
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94342 35600 대비 1350 체결량 10 거래량 535249
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 실시간(장중 체결) 뷰노 94345 35600 대비 1350 체결량 2 거래량 535251
# 지표 개수:   3
# MACD 3617.643919693346
# SIGNAL 2896.463500456071
# OSCILLATOR 721.1804192372751
# 실시간(장중 체결) 뷰노 94346 35650 대비 1400 체결량 265 거래량 535516
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94347 35650 대비 1400 체결량 3 거래량 535519
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94347 35650 대비 1400 체결량 10 거래량 535529
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94349 35700 대비 1450 체결량 60 거래량 535589
# 지표 개수:   3
# MACD 3625.621127670551
# SIGNAL 2898.058942051512
# OSCILLATOR 727.5621856190387
# 실시간(장중 체결) 뷰노 94349 35700 대비 1450 체결량 261 거래량 535850
# 지표 개수:   3
# MACD 3625.621127670551
# SIGNAL 2898.058942051512
# OSCILLATOR 727.5621856190387
# 실시간(장중 체결) 뷰노 94349 35700 대비 1450 체결량 15 거래량 535865
# 지표 개수:   3
# MACD 3625.621127670551
# SIGNAL 2898.058942051512
# OSCILLATOR 727.5621856190387
# 실시간(장중 체결) 뷰노 94350 35650 대비 1400 체결량 100 거래량 535965
# 지표 개수:   3
# MACD 3621.6325236819466
# SIGNAL 2897.261221253791
# OSCILLATOR 724.3713024281556
# 실시간(장중 체결) 뷰노 94350 35750 대비 1500 체결량 13 거래량 535978
# 지표 개수:   3
# MACD 3629.609731659155
# SIGNAL 2898.8566628492326
# OSCILLATOR 730.7530688099223
# 실시간(장중 체결) 뷰노 94350 35750 대비 1500 체결량 84 거래량 536062
# 지표 개수:   3
# MACD 3629.609731659155
# SIGNAL 2898.8566628492326
# OSCILLATOR 730.7530688099223
# 실시간(장중 체결) 뷰노 94351 35750 대비 1500 체결량 112 거래량 536174
# 지표 개수:   3
# MACD 3629.609731659155
# SIGNAL 2898.8566628492326
# OSCILLATOR 730.7530688099223
# 실시간(장중 체결) 뷰노 94351 35750 대비 1500 체결량 651 거래량 536825
# 지표 개수:   3
# MACD 3629.609731659155
# SIGNAL 2898.8566628492326
# OSCILLATOR 730.7530688099223
# 실시간(장중 체결) 뷰노 94351 35800 대비 1550 체결량 855 거래량 537680
# 지표 개수:   3
# MACD 3633.598335647759
# SIGNAL 2899.6543836469536
# OSCILLATOR 733.9439520008054
# 실시간(장중 체결) 뷰노 94351 35850 대비 1600 체결량 2271 거래량 539951
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94352 35800 대비 1550 체결량 16 거래량 539967
# 지표 개수:   3
# MACD 3633.598335647759
# SIGNAL 2899.6543836469536
# OSCILLATOR 733.9439520008054
# 실시간(장중 체결) 뷰노 94354 35850 대비 1600 체결량 100 거래량 540067
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94354 35800 대비 1550 체결량 5 거래량 540072
# 지표 개수:   3
# MACD 3633.598335647759
# SIGNAL 2899.6543836469536
# OSCILLATOR 733.9439520008054
# 실시간(장중 체결) 뷰노 94355 35850 대비 1600 체결량 2 거래량 540074
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94355 35800 대비 1550 체결량 7 거래량 540081
# 지표 개수:   3
# MACD 3633.598335647759
# SIGNAL 2899.6543836469536
# OSCILLATOR 733.9439520008054
# 실시간(장중 체결) 뷰노 94356 35800 대비 1550 체결량 3 거래량 540084
# 지표 개수:   3
# MACD 3633.598335647759
# SIGNAL 2899.6543836469536
# OSCILLATOR 733.9439520008054
# 실시간(장중 체결) 뷰노 94358 35800 대비 1550 체결량 372 거래량 540456
# 지표 개수:   3
# MACD 3633.598335647759
# SIGNAL 2899.6543836469536
# OSCILLATOR 733.9439520008054
# 실시간(장중 체결) 뷰노 94359 35800 대비 1550 체결량 19 거래량 540475
# 지표 개수:   3
# MACD 3633.598335647759
# SIGNAL 2899.6543836469536
# OSCILLATOR 733.9439520008054
# 실시간(장중 체결) 뷰노 94359 35850 대비 1600 체결량 211 거래량 540686
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94359 35900 대비 1650 체결량 370 거래량 541056
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94400 35800 대비 1550 체결량 1 거래량 541057
# 지표 개수:   3
# MACD 3633.598335647759
# SIGNAL 2899.6543836469536
# OSCILLATOR 733.9439520008054
# 실시간(장중 체결) 뷰노 94401 35800 대비 1550 체결량 114 거래량 541171
# 지표 개수:   3
# MACD 3633.598335647759
# SIGNAL 2899.6543836469536
# OSCILLATOR 733.9439520008054
# 실시간(장중 체결) 뷰노 94401 35800 대비 1550 체결량 4 거래량 541175
# 지표 개수:   3
# MACD 3633.598335647759
# SIGNAL 2899.6543836469536
# OSCILLATOR 733.9439520008054
# 실시간(장중 체결) 뷰노 94401 35800 대비 1550 체결량 35 거래량 541210
# 지표 개수:   3
# MACD 3633.598335647759
# SIGNAL 2899.6543836469536
# OSCILLATOR 733.9439520008054
# 실시간(장중 체결) 뷰노 94401 35800 대비 1550 체결량 7 거래량 541217
# 지표 개수:   3
# MACD 3633.598335647759
# SIGNAL 2899.6543836469536
# OSCILLATOR 733.9439520008054
# 실시간(장중 체결) 뷰노 94401 35850 대비 1600 체결량 8 거래량 541225
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94402 35800 대비 1550 체결량 6 거래량 541231
# 지표 개수:   3
# MACD 3633.598335647759
# SIGNAL 2899.6543836469536
# OSCILLATOR 733.9439520008054
# 실시간(장중 체결) 뷰노 94403 35850 대비 1600 체결량 1 거래량 541232
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94404 35800 대비 1550 체결량 105 거래량 541337
# 지표 개수:   3
# MACD 3633.598335647759
# SIGNAL 2899.6543836469536
# OSCILLATOR 733.9439520008054
# 실시간(장중 체결) 뷰노 94404 35850 대비 1600 체결량 1 거래량 541338
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94404 35850 대비 1600 체결량 81 거래량 541419
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94405 35850 대비 1600 체결량 1 거래량 541420
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94405 35850 대비 1600 체결량 5 거래량 541425
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94405 35800 대비 1550 체결량 7 거래량 541432
# 지표 개수:   3
# MACD 3633.598335647759
# SIGNAL 2899.6543836469536
# OSCILLATOR 733.9439520008054
# 실시간(장중 체결) 뷰노 94406 35850 대비 1600 체결량 400 거래량 541832
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94406 35850 대비 1600 체결량 391 거래량 542223
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94406 35800 대비 1550 체결량 70 거래량 542293
# 지표 개수:   3
# MACD 3633.598335647759
# SIGNAL 2899.6543836469536
# OSCILLATOR 733.9439520008054
# 실시간(장중 체결) 뷰노 94406 35800 대비 1550 체결량 6 거래량 542299
# 지표 개수:   3
# MACD 3633.598335647759
# SIGNAL 2899.6543836469536
# OSCILLATOR 733.9439520008054
# 실시간(장중 체결) 뷰노 94407 35900 대비 1650 체결량 190 거래량 542489
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94407 35900 대비 1650 체결량 28 거래량 542517
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94407 35900 대비 1650 체결량 2 거래량 542519
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94407 35850 대비 1600 체결량 4 거래량 542523
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94407 35850 대비 1600 체결량 1 거래량 542524
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94408 35900 대비 1650 체결량 2 거래량 542526
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94409 35900 대비 1650 체결량 1 거래량 542527
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94410 35850 대비 1600 체결량 2 거래량 542529
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94410 35900 대비 1650 체결량 60 거래량 542589
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94410 35850 대비 1600 체결량 7 거래량 542596
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94411 35900 대비 1650 체결량 2 거래량 542598
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94412 35900 대비 1650 체결량 3 거래량 542601
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94412 35900 대비 1650 체결량 1 거래량 542602
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94412 35900 대비 1650 체결량 1 거래량 542603
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94412 35900 대비 1650 체결량 5 거래량 542608
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94413 35900 대비 1650 체결량 3 거래량 542611
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94413 35850 대비 1600 체결량 100 거래량 542711
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94413 35900 대비 1650 체결량 2 거래량 542713
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94413 35900 대비 1650 체결량 462 거래량 543175
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94413 35900 대비 1650 체결량 40 거래량 543215
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94413 35900 대비 1650 체결량 20 거래량 543235
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94413 35900 대비 1650 체결량 100 거래량 543335
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94415 35900 대비 1650 체결량 50 거래량 543385
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94416 35900 대비 1650 체결량 1 거래량 543386
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94417 35900 대비 1650 체결량 1512 거래량 544898
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94417 35900 대비 1650 체결량 832 거래량 545730
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94417 35850 대비 1600 체결량 200 거래량 545930
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94417 35900 대비 1650 체결량 3 거래량 545933
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94418 35900 대비 1650 체결량 5 거래량 545938
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94418 35900 대비 1650 체결량 2 거래량 545940
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94418 35900 대비 1650 체결량 75 거래량 546015
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94418 35850 대비 1600 체결량 25 거래량 546040
# 지표 개수:   3
# MACD 3637.5869396363632
# SIGNAL 2900.4521044446747
# OSCILLATOR 737.1348351916886
# 실시간(장중 체결) 뷰노 94418 35950 대비 1700 체결량 4 거래량 546044
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94418 35950 대비 1700 체결량 24 거래량 546068
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94418 35900 대비 1650 체결량 1 거래량 546069
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94418 35900 대비 1650 체결량 1 거래량 546070
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94419 35900 대비 1650 체결량 3 거래량 546073
# 지표 개수:   3
# MACD 3641.5755436249674
# SIGNAL 2901.249825242395
# OSCILLATOR 740.3257183825722
# 실시간(장중 체결) 뷰노 94419 35950 대비 1700 체결량 8 거래량 546081
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94420 35950 대비 1700 체결량 2 거래량 546083
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94421 35950 대비 1700 체결량 40 거래량 546123
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94424 35950 대비 1700 체결량 1646 거래량 547769
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94424 35950 대비 1700 체결량 12 거래량 549612
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94425 36000 대비 1750 체결량 42 거래량 549654
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94425 35950 대비 1700 체결량 74 거래량 549728
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94425 36000 대비 1750 체결량 1 거래량 549729
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94425 36000 대비 1750 체결량 4 거래량 549733
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94426 36000 대비 1750 체결량 10 거래량 549743
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94427 36000 대비 1750 체결량 32 거래량 549775
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94427 35950 대비 1700 체결량 1 거래량 549776
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94427 36000 대비 1750 체결량 5 거래량 549781
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94428 36000 대비 1750 체결량 5 거래량 549786
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94428 36000 대비 1750 체결량 2 거래량 549788
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94429 35950 대비 1700 체결량 1 거래량 549789
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94429 36000 대비 1750 체결량 1 거래량 549790
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94430 36000 대비 1750 체결량 2 거래량 549792
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94430 35950 대비 1700 체결량 20 거래량 549812
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94430 35950 대비 1700 체결량 161 거래량 549973
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94431 36000 대비 1750 체결량 200 거래량 550173
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94431 36000 대비 1750 체결량 3 거래량 550176
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94431 36000 대비 1750 체결량 13 거래량 550189
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94432 35950 대비 1700 체결량 100 거래량 550289
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94432 36000 대비 1750 체결량 20 거래량 550309
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94432 36000 대비 1750 체결량 2 거래량 550311
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94432 36000 대비 1750 체결량 125 거래량 550436
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94432 36000 대비 1750 체결량 100 거래량 550536
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94433 36000 대비 1750 체결량 1 거래량 550537
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94433 36000 대비 1750 체결량 172 거래량 550709
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94434 35950 대비 1700 체결량 1000 거래량 551709
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94434 35950 대비 1700 체결량 5 거래량 551714
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94435 35950 대비 1700 체결량 16 거래량 551730
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94435 36000 대비 1750 체결량 300 거래량 552030
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94436 36000 대비 1750 체결량 50 거래량 552080
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94436 35950 대비 1700 체결량 1 거래량 552081
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94436 36000 대비 1750 체결량 5 거래량 552086
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94436 36000 대비 1750 체결량 1 거래량 552087
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94437 35950 대비 1700 체결량 10 거래량 552097
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94437 36000 대비 1750 체결량 241 거래량 552338
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94437 35950 대비 1700 체결량 1392 거래량 553730
# 지표 개수:   3
# MACD 3645.5641476135715
# SIGNAL 2902.0475460401162
# OSCILLATOR 743.5166015734553
# 실시간(장중 체결) 뷰노 94437 36000 대비 1750 체결량 551 거래량 554281
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94437 36000 대비 1750 체결량 9 거래량 554290
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94438 36000 대비 1750 체결량 8 거래량 554298
# 지표 개수:   3
# MACD 3649.5527516021757
# SIGNAL 2902.845266837837
# OSCILLATOR 746.7074847643389
# 실시간(장중 체결) 뷰노 94438 35950 대비 1700 체결량 280 거래량 554578
# ...
# SIGNAL 2950.708514701085
# OSCILLATOR 938.1604762173292
# 실시간(장중 체결) 뷰노 104841 38950 대비 4700 체결량 132 거래량 1978647
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104841 38950 대비 4700 체결량 100 거래량 1978747
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104841 38950 대비 4700 체결량 4 거래량 1978751
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104841 38950 대비 4700 체결량 20 거래량 1978771
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104841 39000 대비 4750 체결량 2 거래량 1978773
# 지표 개수:   3
# MACD 3888.868990918414
# SIGNAL 2950.708514701085
# OSCILLATOR 938.1604762173292
# 실시간(장중 체결) 뷰노 104842 38950 대비 4700 체결량 400 거래량 1979173
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104842 38900 대비 4650 체결량 1100 거래량 1980273
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104842 38900 대비 4650 체결량 81 거래량 1980354
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104842 38950 대비 4700 체결량 5 거래량 1980359
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104842 38950 대비 4700 체결량 50 거래량 1980409
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104842 38900 대비 4650 체결량 1 거래량 1980410
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104842 38950 대비 4700 체결량 7 거래량 1980417
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104842 39000 대비 4750 체결량 2 거래량 1980419
# 지표 개수:   3
# MACD 3888.868990918414
# SIGNAL 2950.708514701085
# OSCILLATOR 938.1604762173292
# 실시간(장중 체결) 뷰노 104843 38950 대비 4700 체결량 5 거래량 1980424
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104843 38950 대비 4700 체결량 2 거래량 1980426
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104843 39000 대비 4750 체결량 2 거래량 1980428
# 지표 개수:   3
# MACD 3888.868990918414
# SIGNAL 2950.708514701085
# OSCILLATOR 938.1604762173292
# 실시간(장중 체결) 뷰노 104843 39000 대비 4750 체결량 70 거래량 1980508
# 지표 개수:   3
# MACD 3888.868990918414
# SIGNAL 2950.708514701085
# OSCILLATOR 938.1604762173292
# 실시간(장중 체결) 뷰노 104843 38900 대비 4650 체결량 10 거래량 1980518
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104843 38950 대비 4700 체결량 250 거래량 1980768
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104843 38900 대비 4650 체결량 39 거래량 1980807
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104843 38900 대비 4650 체결량 17 거래량 1980824
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104844 38900 대비 4650 체결량 8 거래량 1980832
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104844 38900 대비 4650 체결량 30 거래량 1980862
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104844 38900 대비 4650 체결량 1 거래량 1980879
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104844 38900 대비 4650 체결량 79 거래량 1980958
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104845 38950 대비 4700 체결량 30 거래량 1980988
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104845 38900 대비 4650 체결량 1 거래량 1980989
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104845 38900 대비 4650 체결량 15 거래량 1981004
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104846 38950 대비 4700 체결량 6 거래량 1981010
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104847 38950 대비 4700 체결량 3 거래량 1981013
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104847 38900 대비 4650 체결량 4 거래량 1981017
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104847 38950 대비 4700 체결량 3 거래량 1981020
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104848 38900 대비 4650 체결량 36 거래량 1981056
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104848 38950 대비 4700 체결량 10 거래량 1981066
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104848 38950 대비 4700 체결량 10 거래량 1981076
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104848 38900 대비 4650 체결량 14 거래량 1981090
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104849 38900 대비 4650 체결량 617 거래량 1981707
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104849 38900 대비 4650 체결량 150 거래량 1981857
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104849 38900 대비 4650 체결량 1 거래량 1981858
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104849 38900 대비 4650 체결량 30 거래량 1981888
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104849 38850 대비 4600 체결량 50 거래량 1981938
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104849 38850 대비 4600 체결량 5 거래량 1981943
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104849 38900 대비 4650 체결량 50 거래량 1981993
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104850 38850 대비 4600 체결량 83 거래량 1982076
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104850 38850 대비 4600 체결량 3 거래량 1982079
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104850 38850 대비 4600 체결량 1 거래량 1982080
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104850 38900 대비 4650 체결량 10 거래량 1982090
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104850 38900 대비 4650 체결량 3 거래량 1982093
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104850 38850 대비 4600 체결량 20 거래량 1982113
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104851 38850 대비 4600 체결량 200 거래량 1982313
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104851 38900 대비 4650 체결량 200 거래량 1982513
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104851 38850 대비 4600 체결량 1 거래량 1982514
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104851 38850 대비 4600 체결량 50 거래량 1982564
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104852 38900 대비 4650 체결량 2 거래량 1982566
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104852 38850 대비 4600 체결량 5 거래량 1982571
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104852 38850 대비 4600 체결량 6 거래량 1982577
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104852 38850 대비 4600 체결량 100 거래량 1982677
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104853 38900 대비 4650 체결량 20 거래량 1982697
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104853 38850 대비 4600 체결량 1 거래량 1982698
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104853 38900 대비 4650 체결량 10 거래량 1982708
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104854 38850 대비 4600 체결량 2 거래량 1982710
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104854 38850 대비 4600 체결량 1 거래량 1982711
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104854 38900 대비 4650 체결량 78 거래량 1982789
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104854 38900 대비 4650 체결량 5 거래량 1982794
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104854 38900 대비 4650 체결량 1 거래량 1982795
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104855 38850 대비 4600 체결량 110 거래량 1982905
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104855 38850 대비 4600 체결량 25 거래량 1982930
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104855 38850 대비 4600 체결량 280 거래량 1983210
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104855 38850 대비 4600 체결량 2 거래량 1983212
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104855 38900 대비 4650 체결량 30 거래량 1983242
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104855 38900 대비 4650 체결량 40 거래량 1983282
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104856 38900 대비 4650 체결량 95 거래량 1983377
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104856 38850 대비 4600 체결량 67 거래량 1983444
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104856 38850 대비 4600 체결량 116 거래량 1983560
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104856 38850 대비 4600 체결량 13 거래량 1983573
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104856 38900 대비 4650 체결량 29 거래량 1983602
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104856 38900 대비 4650 체결량 6 거래량 1983608
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104857 38850 대비 4600 체결량 37 거래량 1983645
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104857 38900 대비 4650 체결량 1 거래량 1983646
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104857 38850 대비 4600 체결량 70 거래량 1983716
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104857 38850 대비 4600 체결량 100 거래량 1983816
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104857 38900 대비 4650 체결량 8 거래량 1983824
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104857 38900 대비 4650 체결량 5 거래량 1983829
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104857 38850 대비 4600 체결량 1 거래량 1983830
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104857 38900 대비 4650 체결량 5 거래량 1983835
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104858 38850 대비 4600 체결량 56 거래량 1983891
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104859 38850 대비 4600 체결량 395 거래량 1984286
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104859 38800 대비 4550 체결량 205 거래량 1984491
# 지표 개수:   3
# MACD 3872.9145749639974
# SIGNAL 2947.517631510201
# OSCILLATOR 925.3969434537962
# 실시간(장중 체결) 뷰노 104859 38850 대비 4600 체결량 5 거래량 1984496
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104859 38850 대비 4600 체결량 2 거래량 1984498
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104859 38850 대비 4600 체결량 25 거래량 1984523
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104859 38850 대비 4600 체결량 2 거래량 1984525
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104900 38850 대비 4600 체결량 77 거래량 1984602
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104900 38850 대비 4600 체결량 64 거래량 1984666
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104900 38850 대비 4600 체결량 27 거래량 1984693
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104901 38850 대비 4600 체결량 32 거래량 1984725
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104902 38850 대비 4600 체결량 32 거래량 1984757
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104902 38850 대비 4600 체결량 19 거래량 1984776
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104902 38850 대비 4600 체결량 4 거래량 1984780
# 지표 개수:   3
# MACD 3876.9031789526052
# SIGNAL 2948.3153523079227
# OSCILLATOR 928.5878266446825
# 실시간(장중 체결) 뷰노 104903 38900 대비 4650 체결량 50 거래량 1984830
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104903 38900 대비 4650 체결량 150 거래량 1984980
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104903 38900 대비 4650 체결량 482 거래량 1985462
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104903 38950 대비 4700 체결량 265 거래량 1985727
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104903 38900 대비 4650 체결량 13 거래량 1985740
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104903 39000 대비 4750 체결량 1 거래량 1985741
# 지표 개수:   3
# MACD 3888.868990918414
# SIGNAL 2950.708514701085
# OSCILLATOR 938.1604762173292
# 실시간(장중 체결) 뷰노 104903 38950 대비 4700 체결량 1 거래량 1985742
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
# 실시간(장중 체결) 뷰노 104903 38900 대비 4650 체결량 99 거래량 1985841
# 지표 개수:   3
# MACD 3880.8917829412057
# SIGNAL 2949.113073105643
# OSCILLATOR 931.778709835563
# 실시간(장중 체결) 뷰노 104904 39000 대비 4750 체결량 600 거래량 1986441
# 지표 개수:   3
# MACD 3888.868990918414
# SIGNAL 2950.708514701085
# OSCILLATOR 938.1604762173292
# 실시간(장중 체결) 뷰노 104904 39000 대비 4750 체결량 622 거래량 1987063
# 지표 개수:   3
# MACD 3888.868990918414
# SIGNAL 2950.708514701085
# OSCILLATOR 938.1604762173292
# 실시간(장중 체결) 뷰노 104904 39050 대비 4800 체결량 5 거래량 1987068
# 지표 개수:   3
# MACD 3892.857594907018
# SIGNAL 2951.5062354988054
# OSCILLATOR 941.3513594082128
# 실시간(장중 체결) 뷰노 104904 39000 대비 4750 체결량 12 거래량 1987080
# 지표 개수:   3
# MACD 3888.868990918414
# SIGNAL 2950.708514701085
# OSCILLATOR 938.1604762173292
# 실시간(장중 체결) 뷰노 104904 38950 대비 4700 체결량 88 거래량 1987168
# 지표 개수:   3
# MACD 3884.88038692981
# SIGNAL 2949.910793903364
# OSCILLATOR 934.9695930264461
